# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gapminder = pd.read_csv('boxdata_q.csv')
#gapminder.head(n=10)

# %%
sns.catplot(x='Model', y='Avg_return', 
            data = gapminder,
            jitter = '0.25')

# %%
sns.catplot(x = 'Model', 
            y = 'Avg_return', 
            data = gapminder,
            jitter = False,
            height = 4,
            aspect=1.5)

# %%
sns.catplot(x='Model', y = 'Avg_return', 
            data = gapminder,
            kind = 'box',
            height = 4,
            aspect=1.5)

# %%
# make boxplot with Catplot
sns.catplot(x='Model', 
            y='Avg_return',
            kind="box",
            data=gapminder,
            height=4,
            aspect=1.5)
# add data points to boxplot with stripplot
sns.stripplot(x='Model', 
              y='Avg_return',
              data=gapminder,
              alpha=0.3,
              jitter=0.2,
              color='k')
# Out:
# <AxesSubplot:xlabel='Model', ylabel='Avg_return'>

# %%
sns.catplot(x='Model',
            y='Avg_return', 
            data=gapminder,
            height=4,
            aspect=1.5,
            kind='boxen')

# %%
gapminder.boxplot(by="Model", column="Avg_return", grid=False)
# Out:
# <AxesSubplot:title={'center':'Avg_return'}, xlabel='Model'>

# %%
# make boxplot with Seaborn
bplot=sns.boxplot(y='Avg_return', x='Model', 
                 data=gapminder, 
                 width=0.5,
                 palette="colorblind")
 

# add stripplot to boxplot with Seaborn
bplot=sns.stripplot(y='Avg_return', x='Model', 
                   data=gapminder, 
                   jitter=True, 
                   marker='o', 
                   alpha=0.5,
                   color='black')

# %%
# plot boxplot with seaborn
bplot=sns.boxplot(y='Avg_return', x='Model', 
                 data=gapminder, 
                 width=0.2,
                 palette="colorblind")
 
# add swarmplot
bplot=sns.swarmplot(y='Avg_return', x='Model',
              data=gapminder, 
              #color='gray',
              palette="deep",
              alpha=.8)

bplot.axes.set_title("Performance on memory task",fontsize=16)
bplot.set_xlabel("LSTM variant",fontsize=14) 
bplot.set_ylabel("Avg return per episode",fontsize=14)
bplot.tick_params(labelsize=10)
# Out:
# /home/rvdweerd/miniconda3/envs/rlcourse-sb3c/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# save as jpeg
bplot.figure.savefig("boxplot_example_q.jpg", format='jpg', dpi=100)

# %%
gapminder_v = pd.read_csv('boxdata_v.csv')

# %%
# plot boxplot with seaborn
bplot=sns.boxplot(y='Avg_return', x='Model', 
                 data=gapminder_v, 
                 width=0.2,
                 palette="colorblind")
 
# add swarmplot
bplot=sns.swarmplot(y='Avg_return', x='Model',
              data=gapminder_v, 
              #color='gray',
              palette="deep",
              alpha=.8)

bplot.axes.set_title("Performance on memory task",fontsize=16)
bplot.set_xlabel("LSTM variant",fontsize=14) 
bplot.set_ylabel("Avg return per episode",fontsize=14)
bplot.tick_params(labelsize=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_786799/325223894.py in <module>
#       3                  data=gapminder_v,
#       4                  width=0.2,
# ----> 5                  palette="colorblind")
#       6
#       7 # add swarmplot
#
# ~/miniconda3/envs/rlcourse-sb3c/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/miniconda3/envs/rlcourse-sb3c/lib/python3.7/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
# -> 2245                           width, dodge, fliersize, linewidth)
#    2246
#    2247     if ax is None:
#
# ~/miniconda3/envs/rlcourse-sb3c/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     404                  width, dodge, fliersize, linewidth):
#     405
# --> 406         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407         self.establish_colors(color, palette, saturation)
#     408
#
# ~/miniconda3/envs/rlcourse-sb3c/lib/python3.7/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Model'

# %%
# save as jpeg
bplot.figure.savefig("boxplot_example_v.jpg", format='jpg', dpi=100)
